# %% [markdown]
# # Task 01 – Título de la tarea
#
# **Curso:** Machine Learning – UAQ
# **Alumno:** Sebastián Sánchez Frutero
# **Fecha:**

# %% [markdown]
# ## 1. Objetivo
#
# Describir brevemente el objetivo de la tarea.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# %% [markdown]
# ## 2. Carga de datos
#
# En esta sección se cargan los datos desde la carpeta `data/raw`.
# Los datos no se suben al repositorio.

# %%
# Ejemplo de carga de datos (ruta local)
# df = pd.read_csv("../../data/raw/dataset.csv")
# df.head()

# %% [markdown]
# ## 3. Análisis Exploratorio de Datos (EDA)
#
# Se analiza la estructura del conjunto de datos, distribuciones
# y posibles valores atípicos.

# %%
# df.info()
# df.describe()

# %% [markdown]
# ## 4. Preprocesamiento
#
# Limpieza de datos, selección de variables y transformaciones necesarias.

# %%
# Ejemplo:
# X = df.drop("target", axis=1)
# y = df["target"]

# %% [markdown]
# ## 5. Modelo
#
# Descripción del modelo utilizado y justificación.

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## 6. Resultados
#
# Se presentan las métricas obtenidas y visualizaciones relevantes.

# %% [markdown]
# ## 7. Conclusiones
#
# Conclusiones finales y observaciones relevantes.
